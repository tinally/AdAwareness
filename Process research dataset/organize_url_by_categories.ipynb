# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
videos_raw = pd.read_csv('./data/video_Topics_clean.csv')
videos_raw
# Out:
#    KONL05sae4E  VZ9lXgcYL50  6ThU8dS1ItQ  Pzl86IjTpHI  XutXCTwwmYc  \
# 0           27           12           25           26           21
#
#    h6CcxJQq1x8  w22oOw3RIAk  XkgGZobFUq0  1KkVdbUr250  D-Q5mUes_8k  ...  \
# 0            8           19           28           32            9  ...
#
#    ZXXXTD2iKUU  9NYu9STVm-I  4tZKhJBLu_A  NeXMxuNNlE8  JYu3LjgnT9s  \
# 0            5           37           23           10            2
#
#    -W3yiAPR6g4  m064aD_kH40  UTjDWkaR6ZQ  hIqC9IYMUOU  D5H1A7-6E_U
# 0            9           24           11           19           10
#
# [1 rows x 3477 columns]

# %%
# list(videos.columns)

# video_ids = pd.DataFrame(videos.columns) 
# video_ids

# %%
# transpose result

first_row = videos_raw.iloc[0]
videos = pd.DataFrame(first_row) 
videos

videos.columns = ['category_id']
videos
# Out:
#              category_id
# KONL05sae4E           27
# VZ9lXgcYL50           12
# 6ThU8dS1ItQ           25
# Pzl86IjTpHI           26
# XutXCTwwmYc           21
# h6CcxJQq1x8            8
# w22oOw3RIAk           19
# XkgGZobFUq0           28
# 1KkVdbUr250           32
# D-Q5mUes_8k            9
# bqmzpwxDJ9s            9
# mcP_f1UEQVo           33
# -nYhixp7bXI           18
# xtJqw--DGl8           33
# qhbliUq0_r4           30
# EIUSkKTUftU            6
# QEDRDrV55q8            2
# 5AP5zQrJRIg           26
# DlB4hFTAxOo            2
# PsH4uuRT2w8           21
# sPneQzqhh4g            9
# G2wBnjtmmg8            2
# ue5tV4SDldU           21
# QNh18bRw_0k            8
# MX145Tu4MHY            6
# i6O98o2FRHw           16
# 9IZ4CN-CTCM           10
# 5AuLkMBAFZg           33
# Ejf8lk9nYH4            9
# iZIHSn1ILxs            8
# ...                  ...
# _anNRzbAQQ8           37
# c6PPa6sg20E            8
# 2gHeBVyqJRo           10
# ORHnJ1K6mGc            5
# kC43BDxrNhI            6
# ...

# %%
video_ids_list = list(videos.index.values)
print(video_ids_list)
# Out:
# ['KONL05sae4E', 'VZ9lXgcYL50', '6ThU8dS1ItQ', 'Pzl86IjTpHI', 'XutXCTwwmYc', 'h6CcxJQq1x8', 'w22oOw3RIAk', 'XkgGZobFUq0', '1KkVdbUr250', 'D-Q5mUes_8k', 'bqmzpwxDJ9s', 'mcP_f1UEQVo', '-nYhixp7bXI', 'xtJqw--DGl8', 'qhbliUq0_r4', 'EIUSkKTUftU', 'QEDRDrV55q8', '5AP5zQrJRIg', 'DlB4hFTAxOo', 'PsH4uuRT2w8', 'sPneQzqhh4g', 'G2wBnjtmmg8', 'ue5tV4SDldU', 'QNh18bRw_0k', 'MX145Tu4MHY', 'i6O98o2FRHw', '9IZ4CN-CTCM', '5AuLkMBAFZg', 'Ejf8lk9nYH4', 'iZIHSn1ILxs', 'w4kHmbZTvyI', '-S0Azz85mlA', 'gm_n76Dsl0c', 'BhHONpmlxPc', 'g7xSwrdkOMM', 'dNjIpip6e3A', 'B-XHdkCsc5U', '-wXjs6DXoeY', 'QXAYIYdvnys', 'F0WaSy5jNLg', 'hFYCjZvv8y4', '7GKuZu9xkj0', 'r3idOGxm3FA', 'n1ClxdeiIUg', 'lfABnAS5i9Q', 'BntPVmeo7ro', 'mulAi7cno2Y', '1jP4O7rEHQ8', '-iKqr230U9M', 'wTfBWIJ8xQo', '0tteHhYh9rU', 'z01w7kSkDbg', 'baicgyq5UQo', 'n_ERe9-EDSM', 'P9LHzVEPodg', '7jXUWe3MV_c', 'xeo9mVnuuWo', 'LL0s6qOIGr8', '-XidtaAetyQ', 'MhWRyh6ymiM', 'hy2rGDWgOu8', '8zOgbkg6Akw', 'bCxiuuJVT-8', 'azJEx1URHsI', 'biEjueDCnqM', 'mh6vHoyBs58', 'ghex3M
# ...

# %%
# all the food category videos, 916 videos in total
for i in range(1, 9):
    cate = videos[videos["category_id"] == i]
    cate

    cate_list = list(cate.index.values)
    print(cate_list)
# Out:
# ['gm_n76Dsl0c', 'QXAYIYdvnys', 'onPZIVemXKQ', '-T7zyezBkuY', 'e01a4-ClcTs', 'zwY6acYYO3o', 'X5vjQQXauD0', 'KCmOB2L_djk', 'wFl4N4PXlkU', 'rm6d2oy8GRk', 'C7kmm16PoDY', 'YR5YJ3qzIx4', 'rBey5TrvoDw', 'kZV01QAcl20', 'Vf2rlIqGlqM', 'p7pINSytVSc', 'sxlyWieYZsE', '8Ozc-h-29M0', 'lVQsqs7xCb8', 'njY94weLbJ8', '7MJu_aWn1nI', 'xYA7AnVwejo', 'glPUjj0HIvw', 'g6vKa8Be3s8', 'xgO-u83Os_I', '9xGRii6IA1M', 'TElqNU5ytVo', 'l10LhdDwTZc', 'jgC8y0ksrRg', 'EOyQfd7OqIY', '7WbKzWdhx1o', '14c5YOc0ZcU', 'ZsFUqPYlYjQ', 'AU1iq9rqYJ0', 'n4OAtMEXNfc', 'nZH6YKmtQV8', 'MWDwZWCfp64', 'KJXzkUH72cY', '8uK-mCxVl84', 'HdG8LCHCGso', 'RNvmfmZqd9I', 'jmNrvlQ73pU', 'aYNaRnZtYug', 'dI-xHMM8wXE', '7ClI2bp__Bs', '1fqAvkpW5yY', '4dpMzSTI4UM', 'Dz28sQc-1Mk', 'ZzdpNfkh8_0', 'vX6FXRgcKQc', '7MclW0Srs8g', 'rZBxVuTClUc', 'NSvnw3tvPSk', 'L_ycAXqOYr8', 'hBVq3NElVTE', 'vTbG8OQcE1o', '2jaOd1v1B0Q', 'N-rgqDhnLoU', 'rrxE_KCnO44', 'BhYnz0JQKUo', 'wq25qD44hC0', '7ZOKDqjqbX0', '2Dq2-98HliQ', 'eyzWlMZ1Y54', 'dgTrzCMFg9c', 'uLg4kDAGZuw', '-7rgfo
# ...

# %%
# all the car category videos, 239 videos in total 
car = videos[videos["category_id"] == 9]

car_list = list(car.index.values)
print(car_list)
# Out:
# ['D-Q5mUes_8k', 'bqmzpwxDJ9s', 'sPneQzqhh4g', 'Ejf8lk9nYH4', 'dNjIpip6e3A', 'n1ClxdeiIUg', 'wTfBWIJ8xQo', 'Gz-sC-vSIXk', 'kTaCT8ZmdJA', 'pXI340MQ2-o', 'xhH2r3mKFeI', 'tLzfc7Ba12k', 'KKbRAazkiWc', '5u95Zc7AbDM', 'f1PNQwHZuJc', 'HxznTayRCYQ', 't5UjmHOl4pU', 'D_Uhig7L22c', 'MX3P_fcgtHM', 'qjKMAolOf6E', 'lLblbGzXQGY', 'goZODLC7fao', 'Q285dYl2mZI', 'xkt8L0NtSjA', '75F3CSZcCFs', '9gY0FB9qZJg', 'jqQbiJy1Ys0', '_LmxXeKzbT8', 'xl3uLkAT_C8', 'Ml54UuAoLSo', 'o3PI6HFK3Hk', 'DkcuzQRpVuE', '1t1dgE25wEU', '14X98i8psts', 'QweNsLesMrM', 'DLGac1KQbsU', 'DV6X7POhdoo', 'ng8LHbaEsj8', 'krhB_An8fT4', 'Fr6FklMc6B0', 'OL946vRUDJg', 'bEiXvISNID4', '1XLyCDsKhGo', 'yX-TZe8SeYk', 'd4m2LDCuADg', 'pvVNY2YC5zI', 'rqp6S6qgVg8', 'ZDuxWGHA-Z4', 'R7JBDzuHVb4', 'I7CZuPiY-4o', 'XvcdllFeFBY', 'SPCR1GBnSy8', '0ji_-OJlVbI', 'VhK5gJDmSc8', '8qIS3rCrrE4', 'Fk6hyUyz0Ko', 'K5fn087Jk4I', 'sqxPcurgxUA', 'e-r7gp51KQU', 'rt_jK-veOs0', 'yD94CV7kLHE', 'fXT3Sma4-rg', 'BlfinjxFEYI', 'xs9Qu7uiokw', '1De5_o_DXH0', 'uhhcaN03tXs', 'HdeX6C
# ...

# %%
# all the household category videos, 87 videos in total
for i in [22, 24]:
    household = videos[videos["category_id"] == i]
    household

    household_list = list(household.index.values)
    print(household_list)
# Out:
# ['7GKuZu9xkj0', 'q-dGW2ataZ8', 'YbKLOybMb30', 'oIFlHYXjcIU', 'qXndoRUKAhM', '__kJ7HsL10Y', '3nKGrlVvabQ', 'lrMD_z_FnNk', 'u6Rhcv0APng', 'NJEKqI1e714', 'aSdqsA3fzLA', '4FLEzXhWQ6g', 'wJukf4ifuKs', '9Qyb0fK6RJM', 'plnNTqye4Qs', 'qdHd735ZGg4', 'HQQs3nl0LcY', 'ezNqB0tsIF4', 'MbJ5t5YWYpY', 'OqHDg-DGWsM', 'ZjNRXfRXnoc', '7is6r6zXFDc', 'PHLxK2QKZ4Q', '14xmGANmavI', 'RKwaILk_VYI', 'X2cs8gnb42A', 'sMnNjTARUEk', '8JAhnmtotIM', '-c7Ca2CY6x8', 'NQp0z1sbtxo', 'Tx4SBSV9KVY', '-iwCVXD_lA4', 'Fiyy3Gc5Mes', 'jwM5_-2Z1JA', 'VIfRqrSjJis', 'dx6z-vDgz_Y', 'PFbeP6YqHzg', 'D5l-H3fj8Rw', 'z7CnMN3xi9w', 'TEsp-IYQaOk', '1jy3Ow_edZM', 'IvwkyXwn8vY', 'Q5qZedMTkkE', 'Rr6qaG8RlUk', 'iQuTPEYg2ow']
# ...
