# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import json as json

import pandas as pd
from pandas.io.json import json_normalize

# %%
eight_m_title = pd.read_csv('./data/8m_title.csv')
eight_m
# Out:
#          video_id                                              title
# 0     zSxaKz2dluw                   Panda Cheese Commercials (All 5)
# 1     7YkDhOxvTPM   Megalomaniac Wine Commercial - John Petrella DOP
# 2     oVKPosgu5ko        RAZZO a marca que brilha e perfuma seu lar!
# 3     z8FxyXumQF4  พ่อ... หยุดแชทหาผมซะที! คลิปซึ้งเตือนสติ นักแช...
# 4     fNppp2dzQTI           CBS Saturday Morning Credits August 1985
# 5     UZrBB3kjJv4                              ANUNCIOS La2 1995 (3)
# 6     aC2zDp5stdQ                          BMW Serie 2 Active Tourer
# 7     bvoR-_a33mI  Various FEN-Okinawa Info & AFRTS Commercials (...
# 8     JMKjykgyY3g                        Jon Medwick Commercial Reel
# 9     j_YCQ8xF5aM  Mazda 2006 Image video - edit 2 - with English...
# 10    w0Nkr-uMZuw                           Anuncios febrero de 1987
# 11    9YJ7aETRt_I  FIRST PROTOTYPE OF MUSTANG - 1960 - Ford Promo...
# 12    UjROfjZJYb8                Adam Carolla rants on Spud Mckenzie
# ...

# %%
eight_m = pd.read_csv('./data/8m_no_title&des.csv')
eight_m["category_id"] = pd.to_numeric(eight_m["category_id"])
eight_m
# Out:
#          video_id  view_count  like_count  dislike_count  favorite_count  \
# 0     zSxaKz2dluw      159115      1198.0           12.0               0
# 1     7YkDhOxvTPM       30309        55.0            1.0               0
# 2     oVKPosgu5ko        3989        25.0            2.0               0
# 3     z8FxyXumQF4      614476      2904.0          101.0               0
# 4     fNppp2dzQTI       20590        29.0            3.0               0
# 5     UZrBB3kjJv4        2922         3.0            0.0               0
# 6     aC2zDp5stdQ        5176         7.0            3.0               0
# 7     bvoR-_a33mI        6230         NaN            NaN               0
# 8     JMKjykgyY3g        2277         2.0            0.0               0
# 9     j_YCQ8xF5aM        4231        12.0            1.0               0
# 10    w0Nkr-uMZuw       85796       128.0            7.0               0
# 11    9YJ7aETRt_I        7998        87.0            2.0               0
# ...

# %%
# Out:
#          video_id  view_count  like_count  dislike_count  favorite_count  \
# 4     fNppp2dzQTI       20590        29.0            3.0               0
# 8     JMKjykgyY3g        2277         2.0            0.0               0
# 13    5evufRFJ694        2761         5.0            1.0               0
# 19    SKmymVOEtww       27715        25.0            4.0               0
# 34    aznmV2U4-Zc        6208        12.0            0.0               0
# 46    ivfS79h7xt4        5349        21.0            2.0               0
# 49    lkP5Ilf7ViU       10806         3.0           21.0               0
# 58    4XKd2S18aUE     1360497      2034.0          131.0               0
# 66    U7hOSp58bDM        5090        10.0            0.0               0
# 67    H6PvAJF2PFA     5941613      6249.0          697.0               0
# 74    NMT5FJdd0Tk       11504        33.0            0.0               0
# 77    VqEfhO5ENrw       81362       252.0            3.0               0
# ...
